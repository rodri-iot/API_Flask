# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
import joblib
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from sklearn.datasets import load_iris
#       4 from sklearn.tree import DecisionTreeClassifier
#       5 import joblib
#
# File ~/Documents/4GEEKS/repos/my_bootcamp/API/web_services/.venv/lib/python3.12/site-packages/sklearn/__init__.py:84
#      70     # We are not importing the rest of scikit-learn during the build
#      71     # process, as it may not be compiled yet
#      72 else:
#    (...)
#      78     # later is linked to the OpenMP runtime to make it possible to introspect
#      79     # it and importing it first would fail if the OpenMP dll cannot be found.
#      80     from . import (
#      81         __check_build,  # noqa: F401
#      82         _distributor_init,  # noqa: F401
#      83     )
# ---> 84     from .base import clone
#      85     from .utils._show_versions import show_versions
#      87     __all__ = [
#      88         "calibration",
#      89         "cluster",
#    (...)
#     130         "show_versions",
#     131     ]
#
# File ~/Documents/4GEEKS/repos/my_bootcamp/API/web_services/.venv/lib/python3.12/site-packages/sklearn/base.py:19
#      17 from ._config import config_context, get_config
#      18 from .exceptions import InconsistentVersionWarning
# ---> 19 from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#      20 from .utils._metadata_requests import _MetadataRequester, _routing_enabled
#      21 from .utils._param_validation import validate_parameter_constraints
#
# File ~/Documents/4GEEKS/repos/my_bootcamp/API/web_services/.venv/lib/python3.12/site-packages/sklearn/utils/__init__.py:11
#       9 from . import _joblib, metadata_routing
#      10 from ._bunch import Bunch
# ---> 11 from ._chunking import gen_batches, gen_even_slices
#      12 from ._estimator_html_repr import estimator_html_repr
#      14 # Make _safe_indexing importable from here for backward compat as this particular
#      15 # helper is considered semi-private and typically very useful for third-party
#      16 # libraries that want to comply with scikit-learn's estimator API. In particular,
#      17 # _safe_indexing was included in our public API documentation despite the leading
#      18 # `_` in its name.
#
# File ~/Documents/4GEEKS/repos/my_bootcamp/API/web_services/.venv/lib/python3.12/site-packages/sklearn/utils/_chunking.py:8
#       5 import numpy as np
#       7 from .._config import get_config
# ----> 8 from ._param_validation import Interval, validate_params
#      11 def chunk_generator(gen, chunksize):
#      12     """Chunk generator, ``gen`` into lists of length ``chunksize``. The last
#      13     chunk may have a length less than ``chunksize``."""
#
# File ~/Documents/4GEEKS/repos/my_bootcamp/API/web_services/.venv/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:14
#      11 from scipy.sparse import csr_matrix, issparse
#      13 from .._config import config_context, get_config
# ---> 14 from .validation import _is_arraylike_not_scalar
#      17 class InvalidParameterError(ValueError, TypeError):
#      18     """Custom exception to be raised when the parameter of a class/method/function
#      19     does not have a valid type or value.
#      20     """
#
# File ~/Documents/4GEEKS/repos/my_bootcamp/API/web_services/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:26
#      24 from .. import get_config as _get_config
#      25 from ..exceptions import DataConversionWarning, NotFittedError, PositiveSpectrumWarning
# ---> 26 from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#      27 from ..utils.fixes import ComplexWarning, _preserve_dia_indices_dtype
#      28 from ._isfinite import FiniteStatus, cy_isfinite
#
# File ~/Documents/4GEEKS/repos/my_bootcamp/API/web_services/.venv/lib/python3.12/site-packages/sklearn/utils/_array_api.py:11
#       8 import scipy.special as special
#      10 from .._config import get_config
# ---> 11 from .fixes import parse_version
#      13 _NUMPY_NAMESPACE_NAMES = {"numpy", "array_api_compat.numpy"}
#      16 def yield_namespaces(include_numpy_namespaces=True):
#
# File ~/Documents/4GEEKS/repos/my_bootcamp/API/web_services/.venv/lib/python3.12/site-packages/sklearn/utils/fixes.py:21
#      19 import scipy
#      20 import scipy.sparse.linalg
# ---> 21 import scipy.stats
#      23 try:
#      24     import pandas as pd
#
# File ~/Documents/4GEEKS/repos/my_bootcamp/API/web_services/.venv/lib/python3.12/site-packages/scipy/stats/__init__.py:614
#     612 from .distributions import *
#     613 from ._morestats import *
# --> 614 from ._multicomp import *
#     615 from ._binomtest import binomtest
#     616 from ._binned_statistic import *
#
# File ~/Documents/4GEEKS/repos/my_bootcamp/API/web_services/.venv/lib/python3.12/site-packages/scipy/stats/_multicomp.py:12
#      10 from scipy.optimize import minimize_scalar
#      11 from scipy.stats._common import ConfidenceInterval
# ---> 12 from scipy.stats._qmc import check_random_state
#      13 from scipy.stats._stats_py import _var
#      15 if TYPE_CHECKING:
#
# File ~/Documents/4GEEKS/repos/my_bootcamp/API/web_services/.venv/lib/python3.12/site-packages/scipy/stats/_qmc.py:36
#      31 from scipy.special import gammainc
#      32 from ._sobol import (
#      33     _initialize_v, _cscramble, _fill_p_cumulative, _draw, _fast_forward,
#      34     _categorize, _MAXDIM
#      35 )
# ---> 36 from ._qmc_cy import (
#      37     _cy_wrapper_centered_discrepancy,
#      38     _cy_wrapper_wrap_around_discrepancy,
#      39     _cy_wrapper_mixture_discrepancy,
#      40     _cy_wrapper_l2_star_discrepancy,
#      41     _cy_wrapper_update_discrepancy,
#      42     _cy_van_der_corput_scrambled,
#      43     _cy_van_der_corput,
#      44 )
#      47 __all__ = ['scale', 'discrepancy', 'geometric_discrepancy', 'update_discrepancy',
#      48            'QMCEngine', 'Sobol', 'Halton', 'LatinHypercube', 'PoissonDisk',
#      49            'MultinomialQMC', 'MultivariateNormalQMC']
#      52 @overload
#      53 def check_random_state(seed: IntNumber | None = ...) -> np.random.Generator:
#
# File <frozen importlib._bootstrap>:645, in parent(self)
#
# KeyboardInterrupt:

# %%
X, y = load_iris(return_X_y=True, as_frame=True)
df_raw = X
df_raw['y'] = y
df_raw.info()
